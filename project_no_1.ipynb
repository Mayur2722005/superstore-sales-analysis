# %% [markdown]
# #       Sales Data Analytics Project (Pandas & Matplotlib)
#
#
# **Role**: Data Analyst
#
# **Objective**: Perform end-to-end sales data analysis using SuperStore CSV data.
#
# **Tools Used**: Pandas, Matplotlib
#
# **Environment**: Google Colab

# %%
# 1. Import Required Libraries

import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['axes.grid'] = True

# %%
# 2. Load Sales Dataset (CSV)

df = pd.read_csv("/content/SuperStore Sales DataSet 1(Sheet1) (1).csv", encoding="cp1252")
df.head()
# Out:
#    Order Date          City       State   Region         Category  \
# 0  01-01-2019  Gaithersburg    Maryland     East        Furniture
# 1  02-01-2019  Gaithersburg    Maryland     East        Furniture
# 2  02-01-2019  Gaithersburg    Maryland     East       Technology
# 3  03-01-2019   Los Angeles  California     West  Office Supplies
# 4  03-01-2019   San Antonio       Texas  Central       Technology
#
#   Sub-Category                                       Product Name   Sales  \
# 0    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...   73.94
# 1    Bookcases  Bush Westfield Collection Bookcases, Medium Ch...  173.94
# 2       Phones                                        GE 30522EE2  231.98
# 3      Storage  Recycled Steel Personal File for Hanging File ...  114.46
# 4  Accessories                Imation Clip USB flash drive - 8 GB   30.08
#
#    Quantity   Profit Payment Mode
# 0         1  28.2668       Online
# 1         3  38.2668       Online
# 2         2  67.2742        Cards
# 3         2  28.6150       Online
# 4         2  -5.2640       Online

# %%
# 3. Dataset Overview

df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    5901 non-null   object
#  1   City          5901 non-null   object
#  2   State         5901 non-null   object
#  3   Region        5901 non-null   object
#  4   Category      5901 non-null   object
#  5   Sub-Category  5901 non-null   object
#  6   Product Name  5901 non-null   object
#  7   Sales         5901 non-null   float64
#  8   Quantity      5901 non-null   int64
#  9   Profit        5901 non-null   float64
#  10  Payment Mode  5901 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 507.2+ KB
#         Order Date           City       State Region         Category  \
# count         5901           5901        5901   5901             5901
# unique         643            452          49      4                3
# top     05-09-2019  New York City  California   West  Office Supplies
# freq            38            563        1189   1901             3569
# mean           NaN            NaN         NaN    NaN              NaN
# std            NaN            NaN         NaN    NaN              NaN
# min            NaN            NaN         NaN    NaN              NaN
# 25%            NaN            NaN         NaN    NaN              NaN
# 50%            NaN            NaN         NaN    NaN              NaN
# 75%            NaN            NaN         NaN    NaN              NaN
# max            NaN            NaN         NaN    NaN              NaN
#
#        Sub-Category       Product Name        Sales     Quantity       Profit  \
# count          5901               5901  5901.000000  5901.000000  5901.000000
# unique           17               1742          NaN          NaN          NaN
# top         Binders  Easy-staple paper          NaN          NaN          NaN
# freq            915                 27          NaN          NaN          NaN
# mean            NaN                NaN   265.345589     3.781901    29.700408
# std             NaN                NaN   474.260645     2.212917   259.589138
# min             NaN                NaN     0.836000     1.000000 -6599.978000
# 25%             NaN                NaN    71.976000     2.000000     1.795500
# 50%             NaN                NaN   128.648000     3.000000     8.502500
# 75%             NaN                NaN   265.170000     5.000000    28.615000
# max             NaN                NaN  9099.930000    14.000000  8399.976000
#
#        Payment Mode
# count          5901
# unique            3
# top             COD
# freq           2453
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %%
# 4. Data Cleaning

df = df.drop_duplicates()
df = df.dropna()
df.shape
# Out:
# (5901, 11)

# %%
# 5. Total Sales Analysis

total_sales = df["Sales"].sum()
print("Total Sales:", total_sales)
# Out:
# Total Sales: 1565804.3232

# %%
# 6. Sales by Category

sales_by_category = df.groupby("Category")["Sales"].sum()
sales_by_category.plot(kind='bar')
plt.title("Sales by Category")
plt.show()

# %%
# 7. Time-Based Sales Trend


df["Order Date"] = pd.to_datetime(df["Order Date"])
df.groupby(df["Order Date"].dt.month)["Sales"].sum().plot()
plt.show()

# %%
# 8. Top Performing Records

top_sales = df.sort_values(by="Sales", ascending=False).head(10)
top_sales
# Out:
#      Order Date           City         State   Region         Category  \
# 430         NaT       Lakewood    New Jersey     East       Technology
# 5236        NaT         Newark      Delaware     East       Technology
# 2654        NaT        Jackson      Michigan  Central  Office Supplies
# 1694 2019-04-10     Providence  Rhode Island     East       Technology
# 4735 2020-05-10  New York City      New York     East       Technology
# 4809        NaT     Sacramento    California     West  Office Supplies
# 254         NaT  San Francisco    California     West  Office Supplies
# 176  2019-01-03        Yonkers      New York     East       Technology
# 3093 2020-01-04  San Francisco    California     West       Technology
# 93   2019-02-02      Arlington      Virginia    South       Technology
#
#      Sub-Category                                       Product Name  \
# 430      Machines   3D Systems Cube Printer, 2nd Generation, Magenta
# 5236      Copiers              Canon imageCLASS 2200 Advanced Copier
# 2654      Binders          GBC DocuBind P400 Electric Binding System
# 1694      Copiers               Hewlett Packard LaserJet 3310 Copier
# 4735     Machines   3D Systems Cube Printer, 2nd Generation, Magenta
# 4809      Binders  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 254      Supplies        High Speed Automatic Electric Letter Opener
# 176      Machines                  Ativa V4110MDD Micro-Cut Shredder
# 3093     Machines          Cubify CubeX 3D Printer Double Head Print
# 93       Machines  HP Designjet T520 Inkjet Large Format Printer ...
#
#          Sales  Quantity     Profit Payment Mode
# 430   9099.930         7  2365.9818          COD
# 5236  5517.970         3  5039.9856          COD
# 2654  5455.960         4  2504.2216          COD
# 1694  5399.910         9  2591.9568        Cards
# 4735  5234.960         4  1351.9896        Cards
# 4809  5107.960         5  1906.4850          COD
# 254   4912.590         3   196.5036        Cards
# 176   4899.930         7  2400.9657          COD
# 3093  4823.984         2   359.9988        Cards
# 93    4749.950         5  2799.9840          COD

# %%
# 9. Contribution Analysis

contribution = (sales_by_category / total_sales) * 100
contribution.plot(kind='pie', autopct='%1.1f%%')
plt.title("Sales Contribution by Category")
plt.show()
